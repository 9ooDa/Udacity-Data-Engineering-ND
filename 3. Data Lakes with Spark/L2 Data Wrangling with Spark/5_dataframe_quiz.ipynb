# %% [markdown]
# # Data Wrangling with DataFrames Coding Quiz
#
# Use this Jupyter notebook to find the answers to the quiz in the previous section. There is an answer key in the next part of the lesson.

# %%
from pyspark.sql import SparkSession

# TODOS: 
# 1) import any other libraries you might need
# 2) instantiate a Spark session 
# 3) read in the data set located at the path "data/sparkify_log_small.json"
# 4) write code to answer the quiz questions 
spark = SparkSession.builder.appName("Wrangling Data Quiz").getOrCreate()

path = "data/sparkify_log_small.json"
user_log = spark.read.json(path)

# %% [markdown]
# # Question 1
#
# Which page did user id "" (empty string) NOT visit?

# %%
# TODO: write your code to answer question 1
user_log.select("page").dropDuplicates().sort("page").show()
user_log.select(["userID", "page"]).where(user_log.userId == "").dropDuplicates().sort("page").collect()
# Out:
# +----------------+
# |            page|
# +----------------+
# |           About|
# |       Downgrade|
# |           Error|
# |            Help|
# |            Home|
# |           Login|
# |          Logout|
# |        NextSong|
# |   Save Settings|
# |        Settings|
# |Submit Downgrade|
# |  Submit Upgrade|
# |         Upgrade|
# +----------------+
# [Row(userID='', page='About'),
#  Row(userID='', page='Help'),
#  Row(userID='', page='Home'),
#  Row(userID='', page='Login')]

# %% [markdown]
# # Question 2 - Reflect
#
# What type of user does the empty string user id most likely refer to?

# %%
# TODO: use this space to explore the behavior of the user with an empty string
user_log.printSchema()
user_log.select(["userId", "level", "page", "userAgent"]).where(user_log.userId == "").collect()
# Out:
# root
#  |-- artist: string (nullable = true)
#  |-- auth: string (nullable = true)
#  |-- firstName: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- itemInSession: long (nullable = true)
#  |-- lastName: string (nullable = true)
#  |-- length: double (nullable = true)
#  |-- level: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- method: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- registration: long (nullable = true)
#  |-- sessionId: long (nullable = true)
#  |-- song: string (nullable = true)
#  |-- status: long (nullable = true)
#  |-- ts: long (nullable = true)
#  |-- userAgent: string (nullable = true)
#  |-- userId: string (nullable = true)
# [Row(userId='', level='free', page='Login', userAgent=None),
#  Row(userId='', level='paid', page='Home', userAgent=None),
#  Row(userId='', level='free', page='Home', userAgent=None),
#  Row(userId='', level='paid', page='Home', userAgent=None),
# ...

# %% [markdown]
# # Question 3
#
# How many female users do we have in the data set?

# %%
# TODO: write your code to answer question 3
user_log.select(["userID", "gender"]).where(user_log.gender == "F").dropDuplicates().count()
# Out:
# 462

# %% [markdown]
# # Question 4
#
# How many songs were played from the most played artist?

# %%
# TODO: write your code to answer question 4
counted_artist = user_log.select(["artist"]).count()
user_log = user_log.withColumn("counts", counted_artist)
user_log.select(["artist","counted_artist"]).sort("artist")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-25-7493a8d03a91> in <module>()
#       1 # TODO: write your code to answer question 4
#       2 counted_artist = user_log.select(["artist"]).count()
# ----> 3 user_log = user_log.withColumn("counts", counted_artist)
#       4 user_log.select(["artist","counted_artist"]).sort("artist")
#
# /opt/spark-2.4.3-bin-hadoop2.7/python/pyspark/sql/dataframe.py in withColumn(self, colName, col)
#    1986
#    1987         """
# -> 1988         assert isinstance(col, Column), "col should be Column"
#    1989         return DataFrame(self._jdf.withColumn(colName, col._jc), self.sql_ctx)
#    1990
#
# AssertionError: col should be Column

# %% [markdown]
# # Question 5 (challenge)
#
# How many songs do users listen to on average between visiting our home page? Please round your answer to the closest integer.

# %%
# TODO: write your code to answer question 5
user_log.
